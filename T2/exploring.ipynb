# %%
import pandas as pd
from pathlib import Path

# %%
DATA_DIR = Path("data")
RAW_DIR = DATA_DIR / "raw"

# %%
# Reading county by cohort estimates
df = pd.read_parquet(RAW_DIR / 'county_by_cohort_estimates.parquet')

# %%
df.head(10)
# Out:
#    state  county  cohort state_name county_name  kfr_aian_female_p1  \
# 0      1       1    1978    Alabama     Autauga                 NaN
# 1      1       1    1979    Alabama     Autauga                 NaN
# 2      1       1    1980    Alabama     Autauga                 NaN
# 3      1       1    1981    Alabama     Autauga                 NaN
# 4      1       1    1982    Alabama     Autauga                 NaN
# 5      1       1    1983    Alabama     Autauga                 NaN
# 6      1       1    1984    Alabama     Autauga                 NaN
# 7      1       1    1985    Alabama     Autauga                 NaN
# 8      1       1    1986    Alabama     Autauga                 NaN
# 9      1       1    1987    Alabama     Autauga                 NaN
#
#    kfr_asian_female_p1  kfr_black_female_p1  kfr_hisp_female_p1  \
# 0                  NaN             0.406183                 NaN
# 1                  NaN             0.341267                 NaN
# ...
